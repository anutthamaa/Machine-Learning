# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
df = pd.read_excel('RIL.xlsx')
df.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price          WAP  \
# 0 2020-12-07     1942.00     1965.00    1942.00      1958.05  1955.633497
# 1 2020-12-04     1963.00     1967.85    1940.00      1946.55  1947.790186
# 2 2020-12-03     1970.00     1981.10    1958.05      1963.45  1964.591710
# 3 2020-12-02     1962.95     1962.95    1935.00      1957.60  1948.341767
# 4 2020-12-01     1935.25     1965.90    1931.00      1954.30  1949.744750
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0        293809          20719             574582722              129734.0
# 1        250336          26897             487602004              115290.0
# 2       1489127          16539            2925526559             1293175.0
# 3        220138          14040             428904060               48462.0
# 4        593339          48089            1156859600              240644.0
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# ...

# %%
df.shape
# Out:
# (2483, 13)

# %%
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
from sklearn.preprocessing import StandardScaler
scaler =  StandardScaler()
num_cols = ['Open Price', 'High Price', 'Low Price', 'Close Price','WAP','No.of Shares','No. of Trades	']
bike_sharing_binning[num_cols] = scaler.fit_transform(bike_sharing_binning[num_cols])

# %%
df['year'] = df['Date'].dt.year
df.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price          WAP  \
# 0 2020-12-07     1942.00     1965.00    1942.00      1958.05  1955.633497
# 1 2020-12-04     1963.00     1967.85    1940.00      1946.55  1947.790186
# 2 2020-12-03     1970.00     1981.10    1958.05      1963.45  1964.591710
# 3 2020-12-02     1962.95     1962.95    1935.00      1957.60  1948.341767
# 4 2020-12-01     1935.25     1965.90    1931.00      1954.30  1949.744750
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0        293809          20719             574582722              129734.0
# 1        250336          26897             487602004              115290.0
# 2       1489127          16539            2925526559             1293175.0
# 3        220138          14040             428904060               48462.0
# 4        593339          48089            1156859600              240644.0
#
# ...

# %%
df.year.unique()
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010],
#       dtype=int64)

# %%
sns.scatterplot(x='year',y='No. of Trades',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='No. of Trades'>

# %%
df.Date.unique()
# Out:
# array(['2020-12-07T00:00:00.000000000', '2020-12-04T00:00:00.000000000',
#        '2020-12-03T00:00:00.000000000', ...,
#        '2010-12-03T00:00:00.000000000', '2010-12-02T00:00:00.000000000',
#        '2010-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483 entries, 0 to 2482
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2483 non-null   datetime64[ns]
#  1   Open Price                 2483 non-null   float64
#  2   High Price                 2483 non-null   float64
#  3   Low Price                  2483 non-null   float64
#  4   Close Price                2483 non-null   float64
#  5   WAP                        2483 non-null   float64
#  6   No.of Shares               2483 non-null   int64
#  7   No. of Trades              2483 non-null   int64
#  8   Total Turnover (Rs.)       2483 non-null   int64
#  9   Deliverable Quantity       2482 non-null   float64
#  10  % Deli. Qty to Traded Qty  2482 non-null   float64
#  11  Spread High-Low            2483 non-null   float64
#  12  Spread Close-Open          2483 non-null   float64
# ...

# %%
df.describe().T
# Out:
#                             count          mean           std           min  \
# Open Price                 2483.0  1.064741e+03  3.091284e+02  6.750000e+02
# High Price                 2483.0  1.076549e+03  3.127310e+02  6.827500e+02
# Low Price                  2483.0  1.051747e+03  3.041876e+02  6.710000e+02
# Close Price                2483.0  1.063290e+03  3.079184e+02  6.762000e+02
# WAP                        2483.0  1.064215e+03  3.084849e+02  6.774816e+02
# No.of Shares               2483.0  1.083871e+06  1.395008e+07  1.684700e+04
# No. of Trades              2483.0  1.513057e+04  1.166572e+04  6.310000e+02
# Total Turnover (Rs.)       2483.0  1.275436e+09  1.780384e+10  1.246774e+07
# Deliverable Quantity       2482.0  7.525986e+05  1.394581e+07  6.632000e+03
# % Deli. Qty to Traded Qty  2482.0  3.455547e+01  1.437030e+01  4.760000e+00
# Spread High-Low            2483.0  2.480209e+01  1.721740e+01  3.100000e+00
# ...

# %%
df.isna().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         1
# % Deli. Qty to Traded Qty    1
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.isna().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         0
# % Deli. Qty to Traded Qty    0
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr))

# Create a custom divergin palette
cmap = sns.diverging_palette(100, 7, s=75, l=40,
                            n=5, center="light", as_cmap=True)
np.fill_diagonal(mask, False)

plt.figure(figsize=(14, 8))
sns.heatmap(corr, mask=mask, center=0, annot=True,
            fmt='.2f', square=True, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
df['No.of Shares'].unique()
# Out:
# array([ 293809,  250336, 1489127, ...,  721216,  723874,  594552],
#       dtype=int64)

# %%
cols = ['Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP']
sns.pairplot(df[cols], diag_kind ='kde')

# %%
cols2 = ['No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
       'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
       'Spread Close-Open']

# %%
sns.pairplot(df[cols2], diag_kind ='kde')
